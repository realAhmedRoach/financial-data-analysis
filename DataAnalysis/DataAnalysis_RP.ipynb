# %%
import quandl
quandl.ApiConfig.api_key = 'yACpi8J95VWoPd_8qYmv'

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# %run ../Helpers.ipynb

# %%
data1 = quandl.get([Data.EY, Data.TBILL], end_date=date_fmt(data_date))

data1 = data1[data1.columns[0]].sub(data1[data1.columns[1]]).dropna()

data1.plot()

# %%
data2 = data1.diff(periods=12)
data2.plot()
plt.axhline(y=-1.5, color='r', alpha=0.4)
plt.axhline(y=1.5, color='r', alpha=0.4)
