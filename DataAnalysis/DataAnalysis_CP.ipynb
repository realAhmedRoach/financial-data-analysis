# %%
import quandl
quandl.ApiConfig.api_key = 'yACpi8J95VWoPd_8qYmv'

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# %run ../Helpers.ipynb

# %%
data1 = quandl.get(Data.DXY + ".4", start_date=years_ago(16), end_date=date_fmt(data_date)).rolling(window=100).mean().pct_change(periods=100)

plt.figure()
data1.plot()
plt.axhline(y=0, color='r', alpha=0.4)

# %%
data1 = quandl.get(Data.DXY + ".4", start_date=years_ago(16), end_date=date_fmt(data_date)).rolling(window=100).mean().pct_change(periods=100).diff(periods=100)

plt.figure()
data1.plot()
plt.axhline(y=0, color='r', alpha=0.4)
