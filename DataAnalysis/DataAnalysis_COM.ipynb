# %%
import quandl
quandl.ApiConfig.api_key = 'yACpi8J95VWoPd_8qYmv'

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# %run ../Helpers.ipynb

# %%
# data_date = date(2008, 1, 1)
data1 = quandl.get(Data.OILINV, start_date=years_ago(15), end_date=date_fmt(data_date)).pct_change(periods=12)
data15 = data1.diff(periods=12)
data2 = quandl.get('OPEC/ORB', start_date=years_ago(15), end_date=date_fmt(data_date))
data3 = quandl.get(Data.OILCAP, start_date=years_ago(15), end_date=date_fmt(data_date)).rolling(window=12).mean()

plt.figure()
data1.plot(title='YoY change in Oil Inventories')
plt.axhline(y=0, color='r', alpha=0.4)

plt.figure()
data15.plot(title='% Chg in YoY change in Oil Inventories')
plt.axhline(y=0, color='r', alpha=0.4)

# %%
plt.figure()
data2.plot()

# %%
plt.figure()
data3.plot()
plt.axhline(y=90, color='r', alpha=0.4)
plt.axhline(y=85, color='r', alpha=0.4)
